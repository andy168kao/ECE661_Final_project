# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import random

import torch
import torch.nn as nn
import torch.nn.functional as F
from google.colab import drive

from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms

import numpy as np

# useful libraries
import torchvision
import torchvision.transforms as transforms
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ece661/final_project/")
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torchvision.models as models

class ResNetEncoder(nn.Module):
    def __init__(self, base_model='resnet50'):
        super(ResNetEncoder, self).__init__()

        # Load the pre-trained base model
        if base_model == 'resnet50':
            self.base_model = models.resnet50(pretrained=True)

        # Modify the first convolution layer if needed
        # self.base_model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)

        # Remove the fully connected layer
        self.base_model.fc = nn.Identity()

    def forward(self, x):
        # Forward through the base model
        x = self.base_model(x)
        return x

# Define the projection head
class ProjectionHead(nn.Module):
    def __init__(self, input_dim=2048, output_dim=4):
        super(ProjectionHead, self).__init__()
        self.fc1 = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        x = self.fc1(x)
        return x

# Define the RotNet model
class RotNet(nn.Module):
    def __init__(self, encoder, projection_head):
        super(RotNet, self).__init__()
        self.encoder = encoder
        self.projection_head = projection_head

    def forward(self, x):
        x = self.encoder(x)
        x = torch.flatten(x, start_dim=1)  # Flatten the output
        x = self.projection_head(x)
        return x

# %%
def model_size_in_mib(model):
    param_size = 0
    for param in model.parameters():
        param_size += param.numel() * param.element_size()
    buffer_size = 0
    for buffer in model.buffers():
        buffer_size += buffer.numel() * buffer.element_size()
    total_size = param_size + buffer_size
    total_size_mib = total_size / (1024 ** 2)  # Convert bytes to MiB
    return total_size_mib

# %%
# print(f"ResNet-18 size: {model_size_in_mib(model)} MiB")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-021e7b9d9019> in <cell line: 1>()
# ----> 1 print(f"ResNet-18 size: {model_size_in_mib(model)} MiB")
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ## Step 2: Set up dataset and dataloader

# %%
class RotNetDataset(torch.utils.data.Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, _ = self.dataset[idx]

        # Randomly choose a rotation angle (0, 90, 180, 270 degrees)
        rotation_label = np.random.choice([0, 1, 2, 3])
        rotated_image = image.rotate(rotation_label * 90)

        # Convert PIL image to tensor
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        rotated_image = transform(rotated_image)

        return rotated_image, rotation_label

# %%
# Data transformation
mean = (0.4914, 0.4822, 0.4465)
std = (0.2470, 0.2435, 0.2616)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])


# Load CIFAR10 dataset
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256

# Load the dataset
original_dataset = CIFAR10(root=DATA_ROOT, train=True, download=True, transform=None)
original_rotational_detection_dataset = CIFAR10(root=DATA_ROOT, train=False, download=True, transform=None)

# Wrap it with RotNetDataset
rotnet_dataset = RotNetDataset(original_dataset)
detection_dataset = RotNetDataset(original_rotational_detection_dataset)

# DataLoader
trainloader = torch.utils.data.DataLoader(rotnet_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=0)
detectionloader = torch.utils.data.DataLoader(detection_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your model and deploy it to GPU devices.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Initialize the base encoder and projection head
base_encoder = ResNetEncoder()
projection_head = ProjectionHead(input_dim=2048, output_dim=4)

# Initialize the RotNet model
model = RotNet(base_encoder, projection_head)

# Move the model to the specified device
model = model.to(device)

# Verify the device
print(next(model.parameters()).device)
# Out:
# cuda:0

# %%
print(f"ResNet-50 size: {model_size_in_mib(model)} MiB")
# Out:
# ResNet-50 size: 89.91033172607422 MiB

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer

# %%
import torch.nn as nn
import torch.optim as optim

import torch.nn as nn
import torch.optim as optim

# Hyperparameters
INITIAL_LR = 0.5
MOMENTUM = 0.9
REG = 1e-4

# Initialize the NT-Xent loss (contrastive loss) for SimCLR
temperature = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %% [markdown]
# ## Step 5: Start the training process.

# %%
import torch.nn as nn
import torch.optim as optim

print("==> Training starts!")
print("=" * 50)

# Learning rate decay setup
DECAY_EPOCHS = 10
DECAY = 0.9
current_learning_rate = INITIAL_LR
EPOCHS = 100
CHECKPOINT_FOLDER = "/content/drive/MyDrive/ece661/final_project/saved_model_rotnet"

# Training loop
start_time = time.time()
for epoch in range(EPOCHS):

    # if epoch % DECAY_EPOCHS == 0 and epoch != 0:
    #     current_learning_rate *= DECAY
    #     for param_group in optimizer.param_groups:
    #         param_group['lr'] = current_learning_rate
    #     print("Current learning rate has decayed to %f" % current_learning_rate)

    model.train()
    total_loss = 0

    for batch_idx, (image, label) in enumerate(trainloader):

        optimizer.zero_grad()

        # Concatenate the pairs of images along the batch dimension
        image = image.to(device)
        label = label.to(device)

        ## Forward pass and calculate loss
        representations = model(image)

        # Calculate loss using both halves
        loss = criterion(representations, label)
        total_loss += loss.item()

        # Backward and optimize
        loss.backward()
        optimizer.step()



    avg_loss = total_loss / len(trainloader)
    print("Epoch [%d/%d], Loss: %.4f" % (epoch + 1, EPOCHS, avg_loss))
    end_time = time.time()
    print("Epoch [%d/%d], Time: %.4f" % (epoch + 1, EPOCHS, end_time-start_time))
    start_time = end_time


    correct_examples = 0
    total_examples = 0
    val_loss = 0

    model.eval()


    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(detectionloader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)

            # compute the output and loss
            output = model.forward(inputs)
            loss = criterion(output, targets)
            val_loss = loss.detach()

            # count the number of correctly predicted samples in the current batch
            _, predicted_results = torch.max(output, 1)
            correct_predictions = (predicted_results == targets)
            correct_examples += correct_predictions.sum().item()
            total_examples += len(targets)
            ####################################

    avg_loss = val_loss / len(detectionloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))


    # Save checkpoint
    if not os.path.exists(CHECKPOINT_FOLDER):
        os.makedirs(CHECKPOINT_FOLDER)
    torch.save(model.state_dict(), os.path.join(CHECKPOINT_FOLDER, 'rotnet_epoch_%d.pth' % epoch))

print("=" * 50)
print("==> Training complete")
# Out:
# ==> Training starts!
# ==================================================
# Epoch [1/100], Loss: 2.0426
# Epoch [1/100], Time: 35.9546
# Validation loss: 0.0349, Validation accuracy: 0.2588
# Epoch [2/100], Loss: 1.3751
# Epoch [2/100], Time: 34.1123
# Validation loss: 0.0342, Validation accuracy: 0.2723
# Epoch [3/100], Loss: 1.3663
# Epoch [3/100], Time: 34.2305
# Validation loss: 0.0348, Validation accuracy: 0.3007
# Epoch [4/100], Loss: 1.3003
# Epoch [4/100], Time: 35.8389
# Validation loss: 0.0318, Validation accuracy: 0.4027
# Epoch [5/100], Loss: 1.1651
# Epoch [5/100], Time: 34.4657
# Validation loss: 0.0276, Validation accuracy: 0.4699
# Epoch [6/100], Loss: 1.1325
# Epoch [6/100], Time: 34.4168
# Validation loss: 0.0255, Validation accuracy: 0.5142
# Epoch [7/100], Loss: 1.1107
# Epoch [7/100], Time: 32.9174
# Validation loss: 0.0232, Validation accuracy: 0.5119
# Epoch [8/100], Loss: 1.1004
# Epoch [8/100], Time: 33.1349
# Validation loss: 0.0330, Validation accuracy: 0.5123
# Epoch [9/100], Loss: 1.0851
# Epoch [9/100], Time: 32.1909
# Validation loss: 0.0298, Validation accuracy: 0.5161
# Epoch [10/100], Loss: 1.0701
# Epoch [10/100], Time: 32.5242
# Validation loss: 0.0268, Validation accuracy: 0.5501
# Epoch [11/100], Loss: 1.0582
# Epoch [11/100], Time: 32.6417
# Validation loss: 0.0260, Validation accuracy: 0.5492
# Epoch [12/100], Loss: 1.0460
# Epoch [12/100], Time: 34.7468
# Validation loss: 0.0258, Validation accuracy: 0.5280
# Epoch [13/100], Loss: 1.0431
# Epoch [13/100], Time: 33.2339
# Validation loss: 0.0294, Validation accuracy: 0.5390
# Epoch [14/100], Loss: 1.0327
# Epoch [14/100], Time: 32.5360
# Validation loss: 0.0256, Validation accuracy: 0.5548
# Epoch [15/100], Loss: 1.0239
# Epoch [15/100], Time: 32.5906
# Validation loss: 0.0306, Validation accuracy: 0.5410
# Epoch [16/100], Loss: 1.0127
# Epoch [16/100], Time: 32.5161
# Validation loss: 0.0297, Validation accuracy: 0.5594
# Epoch [17/100], Loss: 0.9993
# Epoch [17/100], Time: 32.5292
# Validation loss: 0.0237, Validation accuracy: 0.5774
# Epoch [18/100], Loss: 0.9941
# Epoch [18/100], Time: 33.4897
# Validation loss: 0.0195, Validation accuracy: 0.5715
# Epoch [19/100], Loss: 0.9851
# Epoch [19/100], Time: 33.3094
# Validation loss: 0.0198, Validation accuracy: 0.5826
# Epoch [20/100], Loss: 0.9684
# Epoch [20/100], Time: 32.6380
# Validation loss: 0.0212, Validation accuracy: 0.5777
# Epoch [21/100], Loss: 0.9559
# Epoch [21/100], Time: 32.3190
# Validation loss: 0.0301, Validation accuracy: 0.5550
# Epoch [22/100], Loss: 0.9386
# Epoch [22/100], Time: 32.4156
# Validation loss: 0.0256, Validation accuracy: 0.5479
# Epoch [23/100], Loss: 0.9183
# Epoch [23/100], Time: 32.3578
# Validation loss: 0.0227, Validation accuracy: 0.6171
# Epoch [24/100], Loss: 0.9024
# Epoch [24/100], Time: 33.1296
# Validation loss: 0.0326, Validation accuracy: 0.6166
# Epoch [25/100], Loss: 0.9005
# Epoch [25/100], Time: 32.8158
# Validation loss: 0.0136, Validation accuracy: 0.6247
# Epoch [26/100], Loss: 0.8889
# Epoch [26/100], Time: 32.1782
# Validation loss: 0.0294, Validation accuracy: 0.6030
# Epoch [27/100], Loss: 0.8781
# Epoch [27/100], Time: 32.4261
# Validation loss: 0.0215, Validation accuracy: 0.6208
# Epoch [28/100], Loss: 0.8680
# Epoch [28/100], Time: 32.3154
# Validation loss: 0.0284, Validation accuracy: 0.6171
# Epoch [29/100], Loss: 0.8624
# Epoch [29/100], Time: 32.5210
# Validation loss: 0.0337, Validation accuracy: 0.6187
# Epoch [30/100], Loss: 0.8610
# Epoch [30/100], Time: 33.0675
# Validation loss: 0.0197, Validation accuracy: 0.6397
# Epoch [31/100], Loss: 0.8472
# Epoch [31/100], Time: 33.2313
# Validation loss: 0.0180, Validation accuracy: 0.6289
# Epoch [32/100], Loss: 0.8443
# Epoch [32/100], Time: 33.7059
# Validation loss: 0.0223, Validation accuracy: 0.6434
# Epoch [33/100], Loss: 0.8284
# Epoch [33/100], Time: 32.6659
# Validation loss: 0.0123, Validation accuracy: 0.6364
# Epoch [34/100], Loss: 0.8232
# Epoch [34/100], Time: 32.7215
# Validation loss: 0.0254, Validation accuracy: 0.6544
# Epoch [35/100], Loss: 0.8176
# Epoch [35/100], Time: 33.4957
# Validation loss: 0.0255, Validation accuracy: 0.6351
# Epoch [36/100], Loss: 0.8199
# Epoch [36/100], Time: 32.5231
# Validation loss: 0.0217, Validation accuracy: 0.6419
# Epoch [37/100], Loss: 0.8103
# Epoch [37/100], Time: 32.5177
# Validation loss: 0.0274, Validation accuracy: 0.6536
# Epoch [38/100], Loss: 0.7998
# Epoch [38/100], Time: 32.4071
# Validation loss: 0.0300, Validation accuracy: 0.6125
# Epoch [39/100], Loss: 0.7966
# Epoch [39/100], Time: 32.7280
# Validation loss: 0.0242, Validation accuracy: 0.6371
# Epoch [40/100], Loss: 0.7905
# Epoch [40/100], Time: 32.9825
# Validation loss: 0.0255, Validation accuracy: 0.5773
# Epoch [41/100], Loss: 0.7915
# Epoch [41/100], Time: 33.4770
# Validation loss: 0.0301, Validation accuracy: 0.6634
# Epoch [42/100], Loss: 0.7805
# Epoch [42/100], Time: 32.6898
# Validation loss: 0.0194, Validation accuracy: 0.6698
# Epoch [43/100], Loss: 0.7691
# Epoch [43/100], Time: 32.7664
# Validation loss: 0.0256, Validation accuracy: 0.6836
# Epoch [44/100], Loss: 0.7705
# Epoch [44/100], Time: 32.7486
# Validation loss: 0.0163, Validation accuracy: 0.6797
# Epoch [45/100], Loss: 0.7595
# Epoch [45/100], Time: 32.4760
# Validation loss: 0.0249, Validation accuracy: 0.6755
# Epoch [46/100], Loss: 0.7583
# Epoch [46/100], Time: 33.4533
# Validation loss: 0.0232, Validation accuracy: 0.6799
# Epoch [47/100], Loss: 0.7535
# Epoch [47/100], Time: 33.2131
# Validation loss: 0.0162, Validation accuracy: 0.6696
# Epoch [48/100], Loss: 0.7500
# Epoch [48/100], Time: 32.3785
# Validation loss: 0.0201, Validation accuracy: 0.6920
# Epoch [49/100], Loss: 0.7381
# Epoch [49/100], Time: 32.7286
# Validation loss: 0.0241, Validation accuracy: 0.6843
# Epoch [50/100], Loss: 0.7263
# Epoch [50/100], Time: 32.6852
# Validation loss: 0.0248, Validation accuracy: 0.6860
# Epoch [51/100], Loss: 0.7238
# Epoch [51/100], Time: 35.6205
# Validation loss: 0.0233, Validation accuracy: 0.6812
# Epoch [52/100], Loss: 0.7287
# Epoch [52/100], Time: 33.2085
# Validation loss: 0.0118, Validation accuracy: 0.6867
# Epoch [53/100], Loss: 0.7181
# Epoch [53/100], Time: 32.7952
# Validation loss: 0.0094, Validation accuracy: 0.6552
# Epoch [54/100], Loss: 0.7155
# Epoch [54/100], Time: 32.7177
# Validation loss: 0.0189, Validation accuracy: 0.6900
# Epoch [55/100], Loss: 0.7134
# Epoch [55/100], Time: 32.7623
# Validation loss: 0.0144, Validation accuracy: 0.6880
# Epoch [56/100], Loss: 0.7099
# Epoch [56/100], Time: 33.0231
# Validation loss: 0.0213, Validation accuracy: 0.6885
# Epoch [57/100], Loss: 0.7035
# Epoch [57/100], Time: 33.7193
# Validation loss: 0.0176, Validation accuracy: 0.6966
# Epoch [58/100], Loss: 0.7072
# Epoch [58/100], Time: 32.6218
# Validation loss: 0.0242, Validation accuracy: 0.6965
# Epoch [59/100], Loss: 0.6971
# Epoch [59/100], Time: 32.3183
# Validation loss: 0.0096, Validation accuracy: 0.6958
# Epoch [60/100], Loss: 0.6888
# Epoch [60/100], Time: 32.6056
# Validation loss: 0.0137, Validation accuracy: 0.7092
# Epoch [61/100], Loss: 0.6877
# Epoch [61/100], Time: 32.5747
# Validation loss: 0.0129, Validation accuracy: 0.7074
# Epoch [62/100], Loss: 0.6833
# Epoch [62/100], Time: 33.4754
# Validation loss: 0.0272, Validation accuracy: 0.7019
# Epoch [63/100], Loss: 0.6787
# Epoch [63/100], Time: 32.8445
# Validation loss: 0.0164, Validation accuracy: 0.7204
# Epoch [64/100], Loss: 0.6740
# Epoch [64/100], Time: 32.7946
# Validation loss: 0.0116, Validation accuracy: 0.6961
# Epoch [65/100], Loss: 0.6738
# Epoch [65/100], Time: 32.6917
# Validation loss: 0.0198, Validation accuracy: 0.7132
# Epoch [66/100], Loss: 0.6737
# Epoch [66/100], Time: 32.7731
# Validation loss: 0.0304, Validation accuracy: 0.6986
# Epoch [67/100], Loss: 0.6764
# Epoch [67/100], Time: 33.0439
# Validation loss: 0.0145, Validation accuracy: 0.7215
# Epoch [68/100], Loss: 0.6740
# Epoch [68/100], Time: 33.6631
# Validation loss: 0.0208, Validation accuracy: 0.7194
# Epoch [69/100], Loss: 0.6697
# Epoch [69/100], Time: 32.7592
# Validation loss: 0.0072, Validation accuracy: 0.7215
# Epoch [70/100], Loss: 0.6635
# Epoch [70/100], Time: 34.8159
# Validation loss: 0.0127, Validation accuracy: 0.6928
# Epoch [71/100], Loss: 0.6626
# Epoch [71/100], Time: 32.4728
# Validation loss: 0.0102, Validation accuracy: 0.6978
# Epoch [72/100], Loss: 0.6620
# Epoch [72/100], Time: 32.7406
# Validation loss: 0.0105, Validation accuracy: 0.7156
# Epoch [73/100], Loss: 0.6608
# Epoch [73/100], Time: 33.0137
# Validation loss: 0.0191, Validation accuracy: 0.7051
# Epoch [74/100], Loss: 0.6629
# Epoch [74/100], Time: 33.4970
# Validation loss: 0.0101, Validation accuracy: 0.7127
# Epoch [75/100], Loss: 0.6498
# Epoch [75/100], Time: 32.9966
# Validation loss: 0.0115, Validation accuracy: 0.7069
# Epoch [76/100], Loss: 0.6513
# Epoch [76/100], Time: 32.5691
# Validation loss: 0.0083, Validation accuracy: 0.7100
# Epoch [77/100], Loss: 0.6477
# Epoch [77/100], Time: 32.5260
# Validation loss: 0.0125, Validation accuracy: 0.7186
# Epoch [78/100], Loss: 0.6529
# Epoch [78/100], Time: 32.5354
# Validation loss: 0.0187, Validation accuracy: 0.7163
# Epoch [79/100], Loss: 0.6447
# Epoch [79/100], Time: 32.9833
# Validation loss: 0.0142, Validation accuracy: 0.6847
# Epoch [80/100], Loss: 0.6480
# Epoch [80/100], Time: 33.1814
# Validation loss: 0.0345, Validation accuracy: 0.7215
# Epoch [81/100], Loss: 0.6454
# Epoch [81/100], Time: 32.6128
# Validation loss: 0.0124, Validation accuracy: 0.6973
# Epoch [82/100], Loss: 0.6418
# Epoch [82/100], Time: 32.8189
# Validation loss: 0.0250, Validation accuracy: 0.6887
# Epoch [83/100], Loss: 0.6437
# Epoch [83/100], Time: 32.4122
# Validation loss: 0.0150, Validation accuracy: 0.7178
# Epoch [84/100], Loss: 0.6386
# Epoch [84/100], Time: 32.6599
# Validation loss: 0.0267, Validation accuracy: 0.7075
# Epoch [85/100], Loss: 0.6386
# Epoch [85/100], Time: 33.2758
# Validation loss: 0.0176, Validation accuracy: 0.7294
# Epoch [86/100], Loss: 0.6388
# Epoch [86/100], Time: 32.6918
# Validation loss: 0.0148, Validation accuracy: 0.7259
# Epoch [87/100], Loss: 0.6336
# Epoch [87/100], Time: 32.3133
# Validation loss: 0.0216, Validation accuracy: 0.7328
# Epoch [88/100], Loss: 0.6355
# Epoch [88/100], Time: 32.4473
# Validation loss: 0.0056, Validation accuracy: 0.7179
# Epoch [89/100], Loss: 0.6294
# Epoch [89/100], Time: 34.9277
# Validation loss: 0.0236, Validation accuracy: 0.7171
# Epoch [90/100], Loss: 0.6238
# Epoch [90/100], Time: 32.4002
# Validation loss: 0.0176, Validation accuracy: 0.7107
# Epoch [91/100], Loss: 0.6195
# Epoch [91/100], Time: 33.0608
# Validation loss: 0.0279, Validation accuracy: 0.7043
# Epoch [92/100], Loss: 0.6220
# Epoch [92/100], Time: 33.2108
# Validation loss: 0.0233, Validation accuracy: 0.7213
# Epoch [93/100], Loss: 0.6158
# Epoch [93/100], Time: 32.6515
# Validation loss: 0.0133, Validation accuracy: 0.7195
# Epoch [94/100], Loss: 0.6175
# Epoch [94/100], Time: 32.4041
# Validation loss: 0.0204, Validation accuracy: 0.6862
# Epoch [95/100], Loss: 0.6153
# Epoch [95/100], Time: 32.2748
# Validation loss: 0.0187, Validation accuracy: 0.7166
# Epoch [96/100], Loss: 0.6164
# Epoch [96/100], Time: 32.6570
# Validation loss: 0.0227, Validation accuracy: 0.7343
# Epoch [97/100], Loss: 0.6074
# Epoch [97/100], Time: 37.2672
# Validation loss: 0.0120, Validation accuracy: 0.7243
# Epoch [98/100], Loss: 0.5995
# Epoch [98/100], Time: 33.1965
# Validation loss: 0.0142, Validation accuracy: 0.7456
# Epoch [99/100], Loss: 0.6017
# Epoch [99/100], Time: 32.2357
# Validation loss: 0.0152, Validation accuracy: 0.7037
# Epoch [100/100], Loss: 0.5977
# Epoch [100/100], Time: 33.3324
# Validation loss: 0.0132, Validation accuracy: 0.7189
# ==================================================
# ==> Training complete

# %%
model.load_state_dict(torch.load('/content/drive/MyDrive/ece661/final_project/saved_model_rotnet/rotnet_epoch_99.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Step 6: Linear Evaluation

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model.projection_head = nn.Linear(2048, 10)
model = model.to(device)

for param in model.encoder.parameters():
    param.requires_grad = False

# %%
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256

random.seed(0)
torch.manual_seed(0)

transform_classify = transforms.Compose(
                            [transforms.ToTensor(),
                             transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])])



tra_set = CIFAR10(root=DATA_ROOT, train=True, download=True, transform=transform_classify)
val_set = CIFAR10(root=DATA_ROOT, train=False, download=True, transform=transform_classify)


classifier_raw_set_50000 = CIFAR10(root=DATA_ROOT, train=True, download=True, transform=transform_classify)

size = 10000

indices = torch.randperm(len(classifier_raw_set_50000))[:size].tolist()
subset = torch.utils.data.Subset(classifier_raw_set_50000, indices)





normal_train_loader = DataLoader(
    subset,
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=4
)
normal_validate_loader = DataLoader(
    val_set,
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=4
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.nn as nn
import torch.optim as optim

print("==> Training starts!")
print("=" * 50)

# Learning rate decay setup
INITIAL_LR = 0.5
MOMENTUM = 0.9
REG = 1e-4

DECAY_EPOCHS = 8
DECAY = 0.75
current_learning_rate = INITIAL_LR
EPOCHS = 20
CHECKPOINT_FOLDER = "/content/drive/MyDrive/ece661/final_project/saved_model_rotnet"

# Training loop
start_time = time.time()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
for epoch in range(0, EPOCHS):

    if epoch % DECAY_EPOCHS == 0 and epoch != 0:
        current_learning_rate *= DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" % current_learning_rate)


    model.train()
    total_loss = 0

    for batch_idx, (image, label) in enumerate(normal_train_loader):

        image = image.to(device)
        label = label.to(device)

        # compute the output and loss
        output = model.forward(image)
        loss = criterion(output, label)
        train_loss = loss.detach()

        # zero the gradient
        optimizer.zero_grad()

        # backpropagation
        loss.backward()

        # apply gradient and update the weights
        optimizer.step()

        total_loss += train_loss


    avg_loss = total_loss / len(normal_train_loader)
    print("Epoch [%d/%d], Loss: %.4f" % (epoch + 1, EPOCHS, avg_loss))
    end_time = time.time()
    print("Epoch [%d/%d], Time: %.4f" % (epoch + 1, EPOCHS, end_time-start_time))
    start_time = end_time

    model.eval()
    correct_examples = 0
    total_examples = 0
    val_loss = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(normal_validate_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)

            # compute the output and loss
            output = model.forward(inputs)
            loss = criterion(output, targets)
            val_loss = loss.detach()

            # count the number of correctly predicted samples in the current batch
            _, predicted_results = torch.max(output, 1)
            correct_predictions = (predicted_results == targets)
            correct_examples += correct_predictions.sum().item()
            total_examples += len(targets)
            ####################################

    avg_loss = val_loss / len(normal_validate_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))



print("=" * 50)
print("==> Training complete")

# Save checkpoint
if not os.path.exists(CHECKPOINT_FOLDER):
    os.makedirs(CHECKPOINT_FOLDER)
torch.save(model.state_dict(), os.path.join(CHECKPOINT_FOLDER, 'retnet_linear_eval.pth'))
# Out:
# ==> Training starts!
# ==================================================
# Epoch [1/20], Loss: 2.0997
# Epoch [1/20], Time: 2.9236
# Validation loss: 0.0536, Validation accuracy: 0.2120
# Epoch [2/20], Loss: 2.0573
# Epoch [2/20], Time: 5.5360
# Validation loss: 0.0558, Validation accuracy: 0.2301
# Epoch [3/20], Loss: 2.0440
# Epoch [3/20], Time: 7.2666
# Validation loss: 0.0569, Validation accuracy: 0.2323
# Epoch [4/20], Loss: 2.0326
# Epoch [4/20], Time: 5.3200
# Validation loss: 0.0573, Validation accuracy: 0.2482
# Epoch [5/20], Loss: 2.0014
# Epoch [5/20], Time: 5.9454
# Validation loss: 0.0533, Validation accuracy: 0.2333
# Epoch [6/20], Loss: 2.0150
# Epoch [6/20], Time: 7.5056
# Validation loss: 0.0465, Validation accuracy: 0.2441
# Epoch [7/20], Loss: 1.9967
# Epoch [7/20], Time: 5.4371
# Validation loss: 0.0445, Validation accuracy: 0.2557
# Epoch [8/20], Loss: 1.9960
# Epoch [8/20], Time: 7.2493
# Validation loss: 0.0570, Validation accuracy: 0.2581
# Current learning rate has decayed to 0.375000
# Epoch [9/20], Loss: 1.9788
# Epoch [9/20], Time: 5.4144
# Validation loss: 0.0564, Validation accuracy: 0.2682
# Epoch [10/20], Loss: 1.9684
# Epoch [10/20], Time: 6.5417
# Validation loss: 0.0474, Validation accuracy: 0.2630
# Epoch [11/20], Loss: 1.9660
# Epoch [11/20], Time: 6.1837
# Validation loss: 0.0528, Validation accuracy: 0.2608
# Epoch [12/20], Loss: 1.9565
# Epoch [12/20], Time: 5.4801
# Validation loss: 0.0411, Validation accuracy: 0.2708
# Epoch [13/20], Loss: 1.9440
# Epoch [13/20], Time: 7.5603
# Validation loss: 0.0551, Validation accuracy: 0.2488
# Epoch [14/20], Loss: 1.9605
# Epoch [14/20], Time: 5.5835
# Validation loss: 0.0658, Validation accuracy: 0.2631
# Epoch [15/20], Loss: 1.9672
# Epoch [15/20], Time: 7.3423
# Validation loss: 0.0493, Validation accuracy: 0.2653
# Epoch [16/20], Loss: 1.9572
# Epoch [16/20], Time: 6.2325
# Validation loss: 0.0501, Validation accuracy: 0.2709
# Current learning rate has decayed to 0.281250
# Epoch [17/20], Loss: 1.9367
# Epoch [17/20], Time: 6.1070
# Validation loss: 0.0496, Validation accuracy: 0.2812
# Epoch [18/20], Loss: 1.9436
# Epoch [18/20], Time: 6.6204
# Validation loss: 0.0465, Validation accuracy: 0.2777
# Epoch [19/20], Loss: 1.9312
# Epoch [19/20], Time: 5.4066
# Validation loss: 0.0501, Validation accuracy: 0.2556
# Epoch [20/20], Loss: 1.9218
# Epoch [20/20], Time: 7.4534
# Validation loss: 0.0520, Validation accuracy: 0.2792
# ==================================================
# ==> Training complete

# %% [markdown]
# Validation loss: 0.0073, Validation accuracy: 0.7585 for 5000
#
# Validation loss: 0.0027, Validation accuracy: 0.7719
# for 7500
# > 缩进块

# %% [markdown]
# # Step 7: Classifier Finetune

# %%
model.load_state_dict(torch.load('/content/drive/MyDrive/ece661/final_project/saved_model_rotnet/rotnet_epoch_99.pth'))
# Out:
# <All keys matched successfully>

# %%
# Define the new classifier as a separate module
class RotNetClassifier(nn.Module):
    def __init__(self, input_features=2048, features=200, num_classes=10):
        super(RotNetClassifier, self).__init__()
        self.fc1 = nn.Linear(input_features, features)
        self.bn1 = nn.BatchNorm1d(features)
        self.relu1 = nn.ReLU()

        self.fc2 = nn.Linear(features, features)
        self.bn2 = nn.BatchNorm1d(features)
        self.relu2 = nn.ReLU()

        self.fc3 = nn.Linear(features, num_classes)

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu2(x)

        x = self.fc3(x)
        return x

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

classifier = RotNetClassifier()

model.projection_head = classifier
model = model.to(device)

# %%
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256

random.seed(0)
torch.manual_seed(0)

transform_classify = transforms.Compose(
                            [transforms.ToTensor(),
                             transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])])



tra_set = CIFAR10(root=DATA_ROOT, train=True, download=True, transform=transform_classify)
val_set = CIFAR10(root=DATA_ROOT, train=False, download=True, transform=transform_classify)


classifier_raw_set_50000 = CIFAR10(root=DATA_ROOT, train=True, download=True, transform=transform_classify)

size = 50000

indices = torch.randperm(len(classifier_raw_set_50000))[:size].tolist()
subset = torch.utils.data.Subset(classifier_raw_set_50000, indices)


normal_train_loader = DataLoader(
    subset,
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=4
)
normal_validate_loader = DataLoader(
    val_set,
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=4
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.nn as nn
import torch.optim as optim

print("==> Training starts!")
print("=" * 50)

# Learning rate decay setup
INITIAL_LR = 0.5
MOMENTUM = 0.9
REG = 1e-4

DECAY_EPOCHS = 8
DECAY = 0.75
current_learning_rate = INITIAL_LR
EPOCHS = 20
CHECKPOINT_FOLDER = "/content/drive/MyDrive/ece661/final_project/saved_model_rotnet"

# Training loop
start_time = time.time()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
for epoch in range(0, EPOCHS):

    if epoch % DECAY_EPOCHS == 0 and epoch != 0:
        current_learning_rate *= DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" % current_learning_rate)


    model.train()
    total_loss = 0

    for batch_idx, (image, label) in enumerate(normal_train_loader):

        image = image.to(device)
        label = label.to(device)

        # compute the output and loss
        output = model.forward(image)
        loss = criterion(output, label)
        train_loss = loss.detach()

        # zero the gradient
        optimizer.zero_grad()

        # backpropagation
        loss.backward()

        # apply gradient and update the weights
        optimizer.step()

        total_loss += train_loss


    avg_loss = total_loss / len(normal_train_loader)
    print("Epoch [%d/%d], Loss: %.4f" % (epoch + 1, EPOCHS, avg_loss))
    end_time = time.time()
    print("Epoch [%d/%d], Time: %.4f" % (epoch + 1, EPOCHS, end_time-start_time))
    start_time = end_time

    model.eval()
    correct_examples = 0
    total_examples = 0
    val_loss = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(normal_validate_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)

            # compute the output and loss
            output = model.forward(inputs)
            loss = criterion(output, targets)
            val_loss = loss.detach()

            # count the number of correctly predicted samples in the current batch
            _, predicted_results = torch.max(output, 1)
            correct_predictions = (predicted_results == targets)
            correct_examples += correct_predictions.sum().item()
            total_examples += len(targets)
            ####################################

    avg_loss = val_loss / len(normal_validate_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))



print("=" * 50)
print("==> Training complete")

# Save checkpoint
if not os.path.exists(CHECKPOINT_FOLDER):
    os.makedirs(CHECKPOINT_FOLDER)
torch.save(model.state_dict(), os.path.join(CHECKPOINT_FOLDER, 'ROTNET_with_decoder_size_%d.pth' % size))
# Out:
# ==> Training starts!
# ==================================================
# Epoch [1/20], Loss: 1.3000
# Epoch [1/20], Time: 20.3440
# Validation loss: 0.0410, Validation accuracy: 0.6006
# Epoch [2/20], Loss: 0.9170
# Epoch [2/20], Time: 23.4999
# Validation loss: 0.0358, Validation accuracy: 0.6231
# Epoch [3/20], Loss: 0.8043
# Epoch [3/20], Time: 21.8906
# Validation loss: 0.0250, Validation accuracy: 0.6589
# Epoch [4/20], Loss: 0.7452
# Epoch [4/20], Time: 24.3264
# Validation loss: 0.0202, Validation accuracy: 0.6612
# Epoch [5/20], Loss: 0.6829
# Epoch [5/20], Time: 22.7442
# Validation loss: 0.0287, Validation accuracy: 0.6562
# Epoch [6/20], Loss: 0.6428
# Epoch [6/20], Time: 22.9242
# Validation loss: 0.0199, Validation accuracy: 0.6938
# Epoch [7/20], Loss: 0.6085
# Epoch [7/20], Time: 22.5653
# Validation loss: 0.0139, Validation accuracy: 0.7220
# Epoch [8/20], Loss: 0.5802
# Epoch [8/20], Time: 21.4286
# Validation loss: 0.0256, Validation accuracy: 0.6896
# Current learning rate has decayed to 0.375000
# Epoch [9/20], Loss: 0.4678
# Epoch [9/20], Time: 23.0314
# Validation loss: 0.0143, Validation accuracy: 0.7448
# Epoch [10/20], Loss: 0.4276
# Epoch [10/20], Time: 22.2128
# Validation loss: 0.0378, Validation accuracy: 0.7449
# Epoch [11/20], Loss: 0.4134
# Epoch [11/20], Time: 21.9568
# Validation loss: 0.0225, Validation accuracy: 0.7529
# Epoch [12/20], Loss: 0.4143
# Epoch [12/20], Time: 22.8040
# Validation loss: 0.0202, Validation accuracy: 0.7596
# Epoch [13/20], Loss: 0.3967
# Epoch [13/20], Time: 21.3619
# Validation loss: 0.0230, Validation accuracy: 0.7507
# Epoch [14/20], Loss: 0.3719
# Epoch [14/20], Time: 22.1131
# Validation loss: 0.0379, Validation accuracy: 0.7559
# Epoch [15/20], Loss: 0.3796
# Epoch [15/20], Time: 21.5793
# Validation loss: 0.0424, Validation accuracy: 0.7514
# Epoch [16/20], Loss: 0.3547
# Epoch [16/20], Time: 21.2487
# Validation loss: 0.0144, Validation accuracy: 0.7641
# Current learning rate has decayed to 0.281250
# Epoch [17/20], Loss: 0.2562
# Epoch [17/20], Time: 25.7677
# Validation loss: 0.0206, Validation accuracy: 0.7693
# Epoch [18/20], Loss: 0.2430
# Epoch [18/20], Time: 20.9362
# Validation loss: 0.0042, Validation accuracy: 0.7468
# Epoch [19/20], Loss: 0.2318
# Epoch [19/20], Time: 22.7011
# Validation loss: 0.0593, Validation accuracy: 0.7654
# Epoch [20/20], Loss: 0.2291
# Epoch [20/20], Time: 22.4867
# Validation loss: 0.0149, Validation accuracy: 0.7601
# ==================================================
# ==> Training complete
